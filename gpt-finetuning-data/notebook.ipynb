# %% [markdown]
# <h1>STEP-1 --> IMPORTING ALL DATA</h1>

# %% [markdown]
# <h3>A - DAILY DIALOG</h3>

# %%
from get_formatted_datasets.daily_dialog import DailyDialogProcessor

daily_dialog_processor = DailyDialogProcessor()

daily_dialog_train_data = daily_dialog_processor.get_train_data()
daily_dialog_validation_data = daily_dialog_processor.get_validation_data()

# %% [markdown]
# <h3>B - DATABRICKS DIALOG</h3>

# %%
from get_formatted_datasets.databricks_dolly import DollyProcessor

dolly_processor = DollyProcessor()

dolly_train_data = dolly_processor.get_train_data()
dolly_validation_data = dolly_processor.get_validation_data()

# %% [markdown]
# <h3>C - OASST</h3>

# %%
from get_formatted_datasets.oasst import OASSTProcessor

oasst_processor = OASSTProcessor()

oasst_train_data = oasst_processor.get_train_data()
oasst_validation_data = oasst_processor.get_validation_data()

# %% [markdown]
# <h3>D - OPEN ORCA</h3>

# %%
from get_formatted_datasets.open_orca import OpenOrcaProcessor

open_orca_processor = OpenOrcaProcessor()

openorca_train_data = open_orca_processor.get_train_data()
openorca_validation_data = open_orca_processor.get_validation_data()

# %% [markdown]
# <h3>E - ULTRACHAT</h3>

# %%
from get_formatted_datasets.ultrachat import UltraChatProcessor

ultrachat_processor = UltraChatProcessor()

ultrachat_train_data = ultrachat_processor.get_train_data()
ultrachat_validation_data = ultrachat_processor.get_validation_data()

# %% [markdown]
# <h1>STEP-2 --> SANITIZE THE DATA OF ALL THE DATA SETS</h1>

# %% [markdown]
# NOTE TO SANITIZE THE DATA WE FIRST NEED TO PASS DATA THROUGH DatasetCleaner THEN THE OUTPUT WILL GO THROUGH ConversationFilter THEN THE RESULT DATA WILL GO THROUGH ConversationWindowProcessor

# %% [markdown]
# <h3>A - DAILY DIALOGUE</h3>
